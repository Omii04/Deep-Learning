# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_classes=2,random_state=41,n_informative=1,n_redundant=0,n_clusters_per_class=1,hypercube=False,class_sep=10)

# %%
np.insert(X,0,1,axis=1)
# Out:
# array([[ 1.        , -0.20535429, -2.86386516],
#        [ 1.        , -0.31575309, -0.87698029],
#        [ 1.        , -0.25640262, -2.47773077],
#        ...,
#        [ 1.        , -0.42153598,  0.16589003],
#        [ 1.        ,  0.37325639,  0.47467773],
#        [ 1.        , -0.06012331, -1.30409991]])

# %%
plt.fig_size=(10,6)
plt.scatter(X[:,0],X[:,1],c=y,cmap="winter")

# %%
def perceptron(X,y):
    X=np.insert(X,0,1,axis=1)
    weights=np.ones(X.shape[1])
    lr=0.1
    
    for i in range(1000):
        j=np.random.randint(0,100)
        y_hat=step(np.dot(X[j],weights))
        weights=weights+lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept,coef=perceptron(X,y)
intercept,coef
# Out:
# (np.float64(0.6000000000000001), array([0.35853885, 1.53815931]))

# %%
m=-(coef[0]/coef[1])
b=-(intercept/coef[1])
