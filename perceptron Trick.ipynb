# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
X,y=make_classification(n_samples=100,n_features=20,n_classes=2,random_state=42,n_informative=10,n_redundant=10,n_clusters_per_class=1,hypercube=False,class_sep=10)
